# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import explained_variance_score
from sklearn.metrics import confusion_matrix

# %%
X_train = pd.read_csv('X_train.csv')
X_test = pd.read_csv('X_test.csv')
y_train = pd.read_csv('y_train.csv')
y_test = pd.read_csv('y_test.csv')

# %%
X_train = X_train.drop(columns=['Date'], axis=1)
X_test = X_test.drop(columns=['Date'], axis=1)

# %%
train = X_train
train = pd.merge(X_train, y_train, on=['Unnamed: 0'])

# %%
train.describe()
# Out:
#          Unnamed: 0        Suburb         Rooms       SellerG      Postcode  \
# count  36324.000000  36324.000000  36324.000000  36324.000000  36324.000000
# mean   31571.526236    180.861744      3.067008    206.922475   3122.890183
# std    18206.705164    104.101444      0.948628    121.279734    125.441498
# min        0.000000      0.000000      1.000000      0.000000   3000.000000
# 25%    15859.750000     88.000000      2.000000    108.000000   3051.000000
# 50%    31634.500000    176.000000      3.000000    225.000000   3103.000000
# 75%    47345.250000    275.000000      4.000000    308.000000   3163.000000
# max    63020.000000    369.000000     31.000000    421.000000   3980.000000
#
#          Regionname  Propertycount      Distance   CouncilArea        Type_h  \
# count  36324.000000   36324.000000  36324.000000  36324.000000  36324.000000
# mean       3.458099    7575.582838     12.691188     14.039753      0.702841
# std        2.120059    4459.081842      7.555479     10.134699      0.457013
# min        0.000000      39.000000      0.000000      0.000000      0.000000
# 25%        2.000000    4294.000000      7.000000      6.000000      0.000000
# 50%        4.000000    6567.000000     11.700000     12.000000      1.000000
# 75%        5.000000   10412.000000     16.700000     22.000000      1.000000
# max        7.000000   21650.000000     55.800000     33.000000      1.000000
#
#              Type_t        Type_u     Method_PI      Method_S     Method_SA  \
# count  36324.000000  36324.000000  36324.000000  36324.000000  36324.000000
# mean       0.103953      0.193206      0.123224      0.631759      0.007488
# std        0.305204      0.394818      0.328699      0.482334      0.086211
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      1.000000      0.000000
# 75%        0.000000      0.000000      0.000000      1.000000      0.000000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#           Method_SP     Method_VB         Price
# count  36324.000000  36324.000000  3.632400e+04
# mean       0.133080      0.104449  9.957164e+05
# std        0.339666      0.305846  5.941235e+05
# min        0.000000      0.000000  8.500000e+04
# 25%        0.000000      0.000000  6.180000e+05
# 50%        0.000000      0.000000  8.300000e+05
# 75%        0.000000      0.000000  1.210000e+06
# max        1.000000      1.000000  1.120000e+07

# %% [markdown]
# ### Random Forest Implementation

# %%
rf_regressor = RandomForestRegressor(n_estimators=28,random_state=0)
rf_regressor.fit(X_train,y_train)
rf_regressor.score(X_test,y_test)
rf_pred =rf_regressor.predict(X_test)
rf_score=rf_regressor.score(X_test,y_test)
expl_rf = explained_variance_score(rf_pred,y_test)

# %%
# In order to calculate the model score
pd.DataFrame({
    "Score": [rf_score], 
    "Explained Variance Score": [expl_rf]
})
# Out:
#       Score  Explained Variance Score
# 0  0.830141                  0.797066

# %% [markdown]
# ### Shap Analysis

# %%
! pip install shap

import shap

explainer = shap.TreeExplainer(rf_regressor)
# Out:
# Requirement already satisfied: shap in c:\users\caesar\anaconda3\lib\site-packages (0.41.0)
# Requirement already satisfied: slicer==0.0.7 in c:\users\caesar\anaconda3\lib\site-packages (from shap) (0.0.7)
# Requirement already satisfied: packaging>20.9 in c:\users\caesar\anaconda3\lib\site-packages (from shap) (21.3)
# Requirement already satisfied: tqdm>4.25.0 in c:\users\caesar\anaconda3\lib\site-packages (from shap) (4.64.1)
# Requirement already satisfied: pandas in c:\users\caesar\anaconda3\lib\site-packages (from shap) (1.4.4)
# Requirement already satisfied: scikit-learn in c:\users\caesar\anaconda3\lib\site-packages (from shap) (1.0.2)
# Requirement already satisfied: numpy in c:\users\caesar\anaconda3\lib\site-packages (from shap) (1.21.5)
# Requirement already satisfied: cloudpickle in c:\users\caesar\anaconda3\lib\site-packages (from shap) (2.0.0)
# Requirement already satisfied: scipy in c:\users\caesar\anaconda3\lib\site-packages (from shap) (1.9.1)
# Requirement already satisfied: numba in c:\users\caesar\anaconda3\lib\site-packages (from shap) (0.55.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\caesar\anaconda3\lib\site-packages (from packaging>20.9->shap) (3.0.9)
# Requirement already satisfied: colorama in c:\users\caesar\anaconda3\lib\site-packages (from tqdm>4.25.0->shap) (0.4.5)
# Requirement already satisfied: setuptools in c:\users\caesar\anaconda3\lib\site-packages (from numba->shap) (63.4.1)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in c:\users\caesar\anaconda3\lib\site-packages (from numba->shap) (0.38.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\caesar\anaconda3\lib\site-packages (from pandas->shap) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\caesar\anaconda3\lib\site-packages (from pandas->shap) (2022.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\caesar\anaconda3\lib\site-packages (from scikit-learn->shap) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\caesar\anaconda3\lib\site-packages (from scikit-learn->shap) (1.1.0)
# Requirement already satisfied: six>=1.5 in c:\users\caesar\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas->shap) (1.16.0)

# %% [markdown]
# ### Lime Analysis

# %%
! pip install lime

import lime
from lime import lime_tabular
# Out:
# Collecting lime
#   Downloading lime-0.2.0.1.tar.gz (275 kB)
#      ------------------------------------ 275.7/275.7 kB 395.1 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: matplotlib in c:\users\caesar\anaconda3\lib\site-packages (from lime) (3.5.2)
# Requirement already satisfied: numpy in c:\users\caesar\anaconda3\lib\site-packages (from lime) (1.21.5)
# Requirement already satisfied: scipy in c:\users\caesar\anaconda3\lib\site-packages (from lime) (1.9.1)
# Requirement already satisfied: tqdm in c:\users\caesar\anaconda3\lib\site-packages (from lime) (4.64.1)
# Requirement already satisfied: scikit-learn>=0.18 in c:\users\caesar\anaconda3\lib\site-packages (from lime) (1.0.2)
# Requirement already satisfied: scikit-image>=0.12 in c:\users\caesar\anaconda3\lib\site-packages (from lime) (0.19.2)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\caesar\anaconda3\lib\site-packages (from scikit-image>=0.12->lime) (1.3.0)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in c:\users\caesar\anaconda3\lib\site-packages (from scikit-image>=0.12->lime) (9.2.0)
# Requirement already satisfied: tifffile>=2019.7.26 in c:\users\caesar\anaconda3\lib\site-packages (from scikit-image>=0.12->lime) (2021.7.2)
# Requirement already satisfied: networkx>=2.2 in c:\users\caesar\anaconda3\lib\site-packages (from scikit-image>=0.12->lime) (2.8.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\caesar\anaconda3\lib\site-packages (from scikit-image>=0.12->lime) (21.3)
# Requirement already satisfied: imageio>=2.4.1 in c:\users\caesar\anaconda3\lib\site-packages (from scikit-image>=0.12->lime) (2.19.3)
# Requirement already satisfied: joblib>=0.11 in c:\users\caesar\anaconda3\lib\site-packages (from scikit-learn>=0.18->lime) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\caesar\anaconda3\lib\site-packages (from scikit-learn>=0.18->lime) (2.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\caesar\anaconda3\lib\site-packages (from matplotlib->lime) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\caesar\anaconda3\lib\site-packages (from matplotlib->lime) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\caesar\anaconda3\lib\site-packages (from matplotlib->lime) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\caesar\anaconda3\lib\site-packages (from matplotlib->lime) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\caesar\anaconda3\lib\site-packages (from matplotlib->lime) (1.4.2)
# Requirement already satisfied: colorama in c:\users\caesar\anaconda3\lib\site-packages (from tqdm->lime) (0.4.5)
# Requirement already satisfied: six>=1.5 in c:\users\caesar\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->lime) (1.16.0)
# Building wheels for collected packages: lime
#   Building wheel for lime (setup.py): started
#   Building wheel for lime (setup.py): finished with status 'done'
#   Created wheel for lime: filename=lime-0.2.0.1-py3-none-any.whl size=283839 sha256=3781e1dae784704f370c5530286aa349b676e197217d74aa0180aa91d0bbcef1
#   Stored in directory: c:\users\caesar\appdata\local\pip\cache\wheels\ed\d7\c9\5a0130d06d6310bc6cbe55220e6e72dcb8c4eff9a478717066
# Successfully built lime
# Installing collected packages: lime
# Successfully installed lime-0.2.0.1

# %%
predict_fn_rf = lambda x: random_forest.predict_proba(x).astype(float)
X = X_train.values
explainer = lime.lime_tabular.LimeTabularExplainer(X,feature_names = X_train.columns, class_names=['Will Die','Will Survive'], kernel_width=5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24252\3703716901.py in <module>
#       1 train = X_train
# ----> 2 train.assign(y_train)
#
# TypeError: assign() takes 1 positional argument but 2 were given
